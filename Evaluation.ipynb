# %% [markdown]
# <a href="https://colab.research.google.com/github/weichihli/Course496_activities/blob/main/Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

df = pd.read_csv("/content/drive/MyDrive/evaluation.csv")
print(df)

df.index = df['reason']
df = df.sort_values(by = 'frequency' ,ascending = False)

df["cumulativePercentage"] = df["frequency"].cumsum()/df["frequency"].sum()*100

df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x: round(x,2))
print(df)

fig, ax = plt.subplots()
ax.bar(df.index, df["frequency"], color = "C0")

ax.set_xticklabels (df['reason'], rotation =45)

ax2 = ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"], color = "C1", marker = "D", ms = 7, label = df['cumulativePercentage'])
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis = "y", colors = "C0")
ax2.tick_params(axis = "y", colors = "C1")



for index, v in df.iterrows():
          label = round(v['cumulativePercentage'],1)
          plt.annotate(label, xy = (v['reason'], v['cumulativePercentage']))
plt.show()
# Out:
#           reason                   description  frequency
# 0            IBM          Clould Strategy Team          4
# 1            IBM                AI Ethics Team         19
# 2            IBM         Image processing team         12
# 3            SAP                      ERP Team         46
# 4            SAP  Supply Chain Management Team         12
# 5            AWS           Cloud Strategy Team         32
# 6            AWS     Cloud Implementation Team         25
# 7            AWS                      ERP Team          3
# 8            IoT           Cloud security Team         14
# 9            IoT                      ERP Team         41
# 10      Security           Cloud security Team         18
# 11      Security           Cloud Strategy Team         27
# 12           SDN           Cloud security Team         12
# 13           SDN           Cloud Strategy Team         22
# 14           SDN     Cloud Implementation Team         30
# 15  Cryptography           Cloud security Team         71
# 16  Cryptography                      ERP team         24
# 17         Scrum           Cloud Strategy Team         11
# 18         Scrum  Supply Chain Management Team         29
# 19         Scrum                      ERP Team         34
# 20         Scrum     Cloud Implementation Team         10
#                     reason                   description  frequency  \
# reason
# Cryptography  Cryptography           Cloud security Team         71
# SAP                    SAP                      ERP Team         46
# IoT                    IoT                      ERP Team         41
# Scrum                Scrum                      ERP Team         34
# AWS                    AWS           Cloud Strategy Team         32
# SDN                    SDN     Cloud Implementation Team         30
# Scrum                Scrum  Supply Chain Management Team         29
# Security          Security           Cloud Strategy Team         27
# AWS                    AWS     Cloud Implementation Team         25
# Cryptography  Cryptography                      ERP team         24
# SDN                    SDN           Cloud Strategy Team         22
# IBM                    IBM                AI Ethics Team         19
# Security          Security           Cloud security Team         18
# IoT                    IoT           Cloud security Team         14
# SDN                    SDN           Cloud security Team         12
# SAP                    SAP  Supply Chain Management Team         12
# IBM                    IBM         Image processing team         12
# Scrum                Scrum           Cloud Strategy Team         11
# Scrum                Scrum     Cloud Implementation Team         10
# IBM                    IBM          Clould Strategy Team          4
# AWS                    AWS                      ERP Team          3
#
#               cumulativePercentage
# reason
# Cryptography                 14.31
# SAP                          23.59
# IoT                          31.85
# Scrum                        38.71
# AWS                          45.16
# SDN                          51.21
# Scrum                        57.06
# Security                     62.50
# AWS                          67.54
# Cryptography                 72.38
# SDN                          76.81
# IBM                          80.65
# Security                     84.27
# IoT                          87.10
# SDN                          89.52
# SAP                          91.94
# IBM                          94.35
# Scrum                        96.57
# Scrum                        98.59
# IBM                          99.40
# AWS                         100.00
